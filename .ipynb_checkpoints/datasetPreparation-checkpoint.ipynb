# %%
import os 
import cv2
import time
import random
import pandas as pd
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt

# %%
parentDir = "/Users/calvin/Documents/NUIG/Thesis/Movies"

actions = ['handshake', 'waving', 'yawning', 'walking', 'bowing', 'punching', 'standing', 'sitting', 'touchinghead', 'defending', 'reachingup']
video_info = []
for action in actions:
    actionFolder = os.path.join(parentDir, action)
    for videoFile in os.listdir(actionFolder):
        if videoFile.split(".")[-1].lower() == "mp4":
            video = cv2.VideoCapture(os.path.join(actionFolder, videoFile))
            video_info.append([action, videoFile, video.get(cv2.CAP_PROP_FRAME_COUNT)])
        
video_info = pd.DataFrame(video_info)
video_info.columns = ["class", "file", "frames"]
video_info
# Out:
#           class                file  frames
# 0     handshake   handshake_120.MP4   216.0
# 1     handshake   handshake_134.MP4   196.0
# 2     handshake   handshake_108.MP4   214.0
# 3     handshake   handshake_109.MP4   243.0
# 4     handshake   handshake_135.MP4   220.0
# ..          ...                 ...     ...
# 496  reachingup  reachingup_100.MP4   210.0
# 497  reachingup  reachingup_128.MP4   234.0
# 498  reachingup  reachingup_129.MP4   222.0
# 499  reachingup  reachingup_101.MP4   222.0
# 500  reachingup  reachingup_115.MP4   222.0
#
# [501 rows x 3 columns]

# %%
video_info["frames"].value_counts()
# Out:
# 216.0    38
# 209.0    31
# 215.0    27
# 213.0    23
# 208.0    22
#          ..
# 174.0     1
# 191.0     1
# 197.0     1
# 236.0     1
# 287.0     1
# Name: frames, Length: 80, dtype: int64

# %%
sorted(video_info["frames"].values, reverse=True)[:10]
# Out:
# [296.0, 289.0, 287.0, 279.0, 275.0, 267.0, 260.0, 257.0, 255.0, 255.0]

# %%
video_info[video_info["frames"]>=295.0]
# Out:
#          class               file  frames
# 420  defending  defending_121.MP4   296.0

# %%
video_info[video_info["frames"] > 216]
# Out:
#           class                file  frames
# 3     handshake   handshake_109.MP4   243.0
# 4     handshake   handshake_135.MP4   220.0
# 5     handshake   handshake_121.MP4   217.0
# 6     handshake   handshake_137.MP4   223.0
# 7     handshake   handshake_123.MP4   218.0
# ..          ...                 ...     ...
# 495  reachingup  reachingup_114.MP4   218.0
# 497  reachingup  reachingup_128.MP4   234.0
# 498  reachingup  reachingup_129.MP4   222.0
# 499  reachingup  reachingup_101.MP4   222.0
# 500  reachingup  reachingup_115.MP4   222.0
#
# [170 rows x 3 columns]

# %% [markdown]
# ## Load KeyPoint dataset

# %%
video.get(cv2.CAP_PROP_FRAME_WIDTH), video.get(cv2.CAP_PROP_FRAME_HEIGHT), video.get(cv2.CAP_PROP_FRAME_WIDTH) * 0.5 , video.get(cv2.CAP_PROP_FRAME_HEIGHT) * 0.5
# Out:
# (1920.0, 1080.0, 960.0, 540.0)

# %%
def standardize(frame):
    mean = np.mean(frame, axis=0)
    std = np.std(frame, axis=0)+0.000001

    frame = (frame - mean) / std
    return frame

# %%
def load_keyPoints(flatten=False, scale=False):
    dataset, labels, label_track = [], [], 0
    parent_dir = "/Users/calvin/Documents/NUIG/Thesis/gesture-estimator/extractedData/"
    actions = ['handshake', 'waving', 'yawning', 'walking', 'bowing', 'punching', 'standing', 'sitting', 'touchinghead', 'defending', 'reachingup']
    for action in actions:
        label_track += 1
        files = os.listdir(os.path.join(parent_dir, action))
        files.remove(".DS_Store") if ".DS_Store" in files else files
        for video_file in files:
            video_file = np.load(os.path.join(parent_dir, action, video_file))
            flattened_video = []
            for frame in video_file:
                if flatten:
                    frame = frame.reshape(-1)
                if scale:
                    frame[:, [4, 8, 12, 16, 20]] = standardize(frame[:, [4, 8, 12, 16, 20]])
                    frame[:, [5, 9, 13, 17, 21]] = standardize(frame[:, [5, 9, 13, 17, 21]])
                    frame[:, [6, 10, 14, 18]]    = standardize(frame[:, [6, 10, 14, 18]])
                    frame[:,  7] = standardize(frame[:,  7])
                    frame[:, 11] = standardize(frame[:, 11])
                    frame[:, 15] = standardize(frame[:, 15])
                    frame[:, 19] = standardize(frame[:, 19])
                flattened_video.append(frame)
            flattened_video = np.array(flattened_video)
            dataset.append(np.array(flattened_video))
            labels.append(label_track)
    # print("Max distance value:", max_7, max_11, max_15, max_19)
    return dataset, labels, frame

master_dataset, master_labels, frame = load_keyPoints(flatten=False, scale=True)

# %%
test = ["x", "y", "z", "v", "xn", "yn", 'a0', 'd0', 'mx0', 'my0', 'a15', 'd15', 
        'mx15', 'my15','a16', 'd16', 'mx16', 'my16', 'a33', 'd33', 'mx33', 'my33']

indx = [4, 5, 8, 9, 12, 13, 16, 17, 20, 21]

xidx = [4, 8, 12, 16, 20]
yidx = [5, 9, 13, 17, 21]
aidx = [6, 10, 14, 18]
didx = [7, 11, 15, 19]

# %%
sample_df = pd.DataFrame(master_dataset[0][0])
sample_df.columns = ["x", "y", "z", "v", "xn", "yn", 'a0', 'd0', 'mx0', 'my0', 'a15', 'd15', 
                     'mx15', 'my15','a16', 'd16', 'mx16', 'my16', 'a33', 'd33', 'mx33', 'my33']
sample_df
# Out:
#            x         y      z      v        xn        yn        a0        d0  \
# 0   0.551495  0.205116 -0.424  1.000  0.001562 -1.137876  0.434262 -0.777334
# 1   0.559740  0.184547 -0.414  1.000  0.216203 -1.215272  1.845613 -0.284249
# 2   0.564187  0.184015 -0.414  1.000  0.331988 -1.217274  1.845613 -0.284249
# 3   0.567492  0.183304 -0.414  1.000  0.418038 -1.219949  1.881801 -0.284249
# 4   0.544446  0.184139 -0.413  1.000 -0.181967 -1.216808  0.940901 -0.185632
# 5   0.539577  0.183082 -0.413  1.000 -0.308734 -1.220785  0.470450 -0.037707
# 6   0.536726  0.181791 -0.413  1.000 -0.382944 -1.225645  0.289508  0.060911
# 7   0.574541  0.185730 -0.307  1.000  0.601537 -1.210823  1.845613 -0.333558
# 8   0.533537  0.186116 -0.303  1.000 -0.465989 -1.209369 -0.108565  0.159528
# 9   0.560721  0.224587 -0.380  1.000  0.241754 -1.064612  0.434262 -0.777334
# 10  0.543688  0.225452 -0.379  1.000 -0.201692 -1.061357 -0.940901 -0.481483
# 11  0.612668  0.304913 -0.211  1.000  1.594164 -0.762362  0.434262 -0.777334
# 17  0.483574 -0.126636 -1.002510  0.495328  0.483392
# 18  0.472116 -1.393001 -0.288801 -0.184901  0.471874
# 19  0.472116 -0.126636 -1.002510  0.451443  0.471874
# 20  0.472116 -1.364860 -0.403916 -0.130044  0.471874
# 21  0.426286 -0.126636 -1.002510  0.440471  0.437322
# 22  0.426286 -1.364860 -0.438450 -0.108101  0.425805
# 23  0.300254 -0.126636 -1.002510  0.319785  0.299113
# 24  0.288796 -1.336719 -0.703213  0.012585  0.287596
# 25  0.907502 -0.126636 -1.002510  0.297842  0.909535
# 26  0.861672 -1.336719 -0.783793  0.056471  0.863466
# 27  1.262684 -0.126636 -1.002510  0.232014  1.266574
# 28  1.274142 -1.308577 -0.829838  0.078414  1.278092
# 29  1.308514 -0.126636 -1.002510  0.210071  1.312644
# 30  1.308514 -1.280436 -0.875884  0.100356  1.324161
# 31  1.503292 -0.126636 -1.002510  0.286871  1.508440
# 32  1.503292 -1.308577 -0.841350  0.078414  1.508440
# 33 -3.274487 -1.364860 -1.002510 -5.626738 -3.236726
#
# [34 rows x 22 columns]

# %% [markdown]
# ## Frame InterPolation

# %%
def frame_interpolation(video, limit):
    output_video, count = [], 0
    if video.shape[0] < limit:
        while count < limit - video.shape[0]:
            output_video.append(video[count])
            output_video.append(video[count])
            count += 1
        while count < video.shape[0]:
            output_video.append(video[count])
            count += 1
    else:
        while count < 2* (video.shape[0] - limit):
            if count % 2 == 0:
                output_video.append(video[count])
            count += 1
        while count < video.shape[0]:
            output_video.append(video[count])
            count += 1
    return np.array(output_video)    
        
dataset = []
for video in master_dataset:
    dataset.append(frame_interpolation(video, 216))
master_dataset = dataset

# %% [markdown]
# ## Flatten Data

# %%
def flatten_dataset(dataset, level=1):
    reshapped_dataset = []
    for video in dataset:
        if level == 1:
            reshapped_dataset.append(video.reshape(216, 748))
        elif level == 2:
            reshapped_dataset.append(video.reshape(1, 161568))
    return reshapped_dataset

# %% [markdown]
# ## One-Hot Encoding

# %%
def encode_labels(labels):
    encoded_labels = []
    for label in labels:
        tmp = np.zeros(11)
        tmp[label-1] = 1
        encoded_labels.append(tmp)
    return encoded_labels

# %% [markdown]
# ## Shuffle Data

# %%
def shuffle_dataset(dataset, labels):
    shuffledDataset = list(zip(dataset, labels))
    random.shuffle(shuffledDataset)
    return shuffledDataset

# %% [markdown]
# ## Train Test Split

# %%
def train_test_split(shuffledDataset, train_test_ratio = 0.8, flatten_label=False):

    train_test_ratio = round(len(shuffledDataset) * train_test_ratio)
    train, train_label = zip(*shuffledDataset[:train_test_ratio])
    test , test_label  = zip(*shuffledDataset[train_test_ratio:])

    assert len(train) + len(test) == len(shuffledDataset)
    
    train = np.array(train)
    train_label = np.array(train_label)
    
    test = np.array(test)
    test_label = np.array(test_label)
    
    if not flatten_label:
        train_label = train_label.reshape(train.shape[0], 1, 11)
        test_label = test_label.reshape(test.shape[0], 1, 11)
    
    print("Train dataset shape :", train.shape)
    print("Test dataset shape  :", test.shape)
    print("Train label shape   :", train_label.shape)
    print("Test label shape    :", test_label.shape)
    
    return train, train_label, test, test_label

# %% [markdown]
# ## Train Wrapper

# %%
def train_wrapper(model, train, train_label, epochs, callbacks=[]):
    start_timer = time.perf_counter()
    history = model.fit(train, train_label, epochs=epochs, callbacks=callbacks)
    print("Training time: {}".format(time.perf_counter() - start_timer))
    fig, ax = plt.subplots(1)
    fig2, ax2 = plt.subplots(1)
    ax.plot(pd.DataFrame(history.history["loss"], columns=["loss"]), color="red")
    ax2.plot(pd.DataFrame(history.history["categorical_accuracy"], columns=["categorical accuracy"])) 
    return model

# %% [markdown]
# ## Accuracy

# %%
def calculate_accuracy(model, test, test_label, cmap="inferno"):
    start = time.perf_counter()
    df = pd.DataFrame(np.zeros((11, 11)), columns=actions, index=actions)
    predicted = model.predict(test)
    counter = 0
    for i in range(predicted.shape[0]):
        df.iloc[np.argmax(test_label[i]), np.argmax(predicted[i])] += 1 
        if actions[np.argmax(predicted[i])] == actions[np.argmax(test_label[i])]:
            counter +=1     
    print("Accuracy: {}".format(counter/test.shape[0]))
    print("Prediction time for {} samples : {}s".format(test_label.shape[0], round(time.perf_counter() - start), 2))

    return df.style.background_gradient(cmap=cmap)

# %% [markdown]
# ## LSTM Neural Network

# %%
dataset = flatten_dataset(master_dataset, level=1)
labels  = encode_labels(master_labels)
dataset = shuffle_dataset(dataset, labels)
train, train_label, test, test_label = train_test_split(dataset, train_test_ratio = 0.8, flatten_label=True)
# Out:
# Train dataset shape : (401, 216, 748)
# Test dataset shape  : (100, 216, 748)
# Train label shape   : (401, 11)
# Test label shape    : (100, 11)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

model = Sequential()
model.add(LSTM(124, return_sequences=True, activation='LeakyReLU', input_shape=(216, 748)))
model.add(LSTM(64, return_sequences=False, activation='LeakyReLU'))
model.add(Dense(128, activation='LeakyReLU'))
model.add(Dense(64, activation='LeakyReLU'))
model.add(Dense(32, activation='LeakyReLU'))
model.add(Dense(11, activation='softmax'))

model.compile(optimizer=Adam(clipvalue=1.0, learning_rate=0.000001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model = train_wrapper(model, train, train_label, epochs=50, callbacks=[tb_callback])

model.summary()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 4s 190ms/step - loss: 214909779968.0000 - categorical_accuracy: 0.0798
# Epoch 2/50
# 13/13 [==============================] - 2s 192ms/step - loss: 3308192792576.0000 - categorical_accuracy: 0.1222
# Epoch 3/50
#  3/13 [=====>........................] - ETA: 1s - loss: 9778417.0000 - categorical_accuracy: 0.0625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [121], in <cell line: 16>()
#      13 model.add(Dense(11, activation='softmax'))
#      15 model.compile(optimizer=Adam(clipvalue=1.0, learning_rate=0.000001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# ---> 16 model = train_wrapper(model, train, train_label, epochs=50, callbacks=[tb_callback])
#      18 model.summary()
#
# Input In [52], in train_wrapper(model, train, train_label, epochs, callbacks)
#       1 def train_wrapper(model, train, train_label, epochs, callbacks=[]):
#       2     start_timer = time.perf_counter()
# ----> 3     history = model.fit(train, train_label, epochs=epochs, callbacks=callbacks)
#       4     print("Training time: {}".format(time.perf_counter() - start_timer))
#       5     fig, ax = plt.subplots(1)
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/venv/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Deep Neural Network

# %%
dataset = flatten_dataset(master_dataset, level=2)
labels  = encode_labels(master_labels)
dataset = shuffle_dataset(dataset, labels)
train, train_label, test, test_label = train_test_split(dataset, train_test_ratio = 0.8, flatten_label=False)
# Out:
# Train dataset shape : (401, 1, 161568)
# Test dataset shape  : (100, 1, 161568)
# Train label shape   : (401, 1, 11)
# Test label shape    : (100, 1, 11)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

model = Sequential()
model.add(Dense(64, activation='LeakyReLU',input_shape=(1, 161568)))
model.add(Dense(128, activation='LeakyReLU'))
model.add(Dense(64, activation='LeakyReLU'))
model.add(Dense(32, activation='LeakyReLU'))
model.add(Dense(11, activation='softmax'))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model = train_wrapper(model, train, train_label, epochs=50, callbacks=[tb_callback])

model.summary()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 26ms/step - loss: 39.6684 - categorical_accuracy: 0.1122
# Epoch 2/50
# 13/13 [==============================] - 0s 35ms/step - loss: 13.8882 - categorical_accuracy: 0.2893
# Epoch 3/50
# 13/13 [==============================] - 1s 40ms/step - loss: 5.0540 - categorical_accuracy: 0.3641
# Epoch 4/50
# 13/13 [==============================] - 0s 38ms/step - loss: 4.6598 - categorical_accuracy: 0.4663
# Epoch 5/50
# 13/13 [==============================] - 0s 38ms/step - loss: 2.8199 - categorical_accuracy: 0.5087
# Epoch 6/50
# 13/13 [==============================] - 1s 38ms/step - loss: 1.9384 - categorical_accuracy: 0.6110
# Epoch 7/50
# 13/13 [==============================] - 0s 37ms/step - loss: 0.9605 - categorical_accuracy: 0.7357
# Epoch 8/50
# 13/13 [==============================] - 1s 39ms/step - loss: 0.7844 - categorical_accuracy: 0.7506
# Epoch 9/50
# 13/13 [==============================] - 1s 42ms/step - loss: 0.8281 - categorical_accuracy: 0.7606
# Epoch 10/50
# 13/13 [==============================] - 1s 48ms/step - loss: 0.6175 - categorical_accuracy: 0.7830
# Epoch 11/50
# 13/13 [==============================] - 0s 38ms/step - loss: 0.5323 - categorical_accuracy: 0.8254
# Epoch 12/50
# 13/13 [==============================] - 1s 39ms/step - loss: 0.3848 - categorical_accuracy: 0.8853
# Epoch 13/50
# 13/13 [==============================] - 1s 38ms/step - loss: 0.3813 - categorical_accuracy: 0.8903
# Epoch 14/50
# 13/13 [==============================] - 1s 39ms/step - loss: 0.3978 - categorical_accuracy: 0.8778
# Epoch 15/50
# 13/13 [==============================] - 1s 40ms/step - loss: 0.3259 - categorical_accuracy: 0.8878
# Epoch 16/50
# 13/13 [==============================] - 1s 39ms/step - loss: 0.4850 - categorical_accuracy: 0.8454
# Epoch 17/50
# 13/13 [==============================] - 1s 39ms/step - loss: 0.6389 - categorical_accuracy: 0.8304
# Epoch 18/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.7325 - categorical_accuracy: 0.8080
# Epoch 19/50
# 13/13 [==============================] - 1s 42ms/step - loss: 0.8694 - categorical_accuracy: 0.7631
# Epoch 20/50
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2696 - categorical_accuracy: 0.9002
# Epoch 21/50
# 13/13 [==============================] - 1s 42ms/step - loss: 0.1694 - categorical_accuracy: 0.9426
# Epoch 22/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1453 - categorical_accuracy: 0.9626
# Epoch 23/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.2034 - categorical_accuracy: 0.9352
# Epoch 24/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.3149 - categorical_accuracy: 0.9152
# Epoch 25/50
# 13/13 [==============================] - 1s 50ms/step - loss: 0.3788 - categorical_accuracy: 0.8778
# Epoch 26/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.5691 - categorical_accuracy: 0.8379
# Epoch 27/50
# 13/13 [==============================] - 1s 48ms/step - loss: 1.1568 - categorical_accuracy: 0.7606
# Epoch 28/50
# 13/13 [==============================] - 1s 40ms/step - loss: 0.5754 - categorical_accuracy: 0.8479
# Epoch 29/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.4230 - categorical_accuracy: 0.8828
# Epoch 30/50
# 13/13 [==============================] - 1s 45ms/step - loss: 0.5142 - categorical_accuracy: 0.8678
# Epoch 31/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.3272 - categorical_accuracy: 0.8828
# Epoch 32/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1432 - categorical_accuracy: 0.9501
# Epoch 33/50
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1059 - categorical_accuracy: 0.9601
# Epoch 34/50
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0493 - categorical_accuracy: 0.9900
# Epoch 35/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0321 - categorical_accuracy: 0.9900
# Epoch 36/50
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0208 - categorical_accuracy: 0.9950
# Epoch 37/50
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0201 - categorical_accuracy: 0.9925
# Epoch 38/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0225 - categorical_accuracy: 0.9925
# Epoch 39/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 40/50
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0043 - categorical_accuracy: 1.0000
# Epoch 41/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.0052 - categorical_accuracy: 1.0000
# Epoch 42/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 43/50
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 44/50
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 45/50
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 46/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 47/50
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 48/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 49/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 50/50
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Training time: 27.732397208999828
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_82 (Dense)            (None, 1, 64)             10340416
#
#  dense_83 (Dense)            (None, 1, 128)            8320
#
#  dense_84 (Dense)            (None, 1, 64)             8256
#
#  dense_85 (Dense)            (None, 1, 32)             2080
#
#  dense_86 (Dense)            (None, 1, 11)             363
#
# =================================================================
# Total params: 10,359,435
# Trainable params: 10,359,435
# Non-trainable params: 0
# _________________________________________________________________

# %%
calculate_accuracy(model, test, test_label)
# Out:
# Accuracy: 0.92
# <style type="text/css">
# #T_7ef1d_row0_col0, #T_7ef1d_row1_col1, #T_7ef1d_row2_col2, #T_7ef1d_row3_col3, #T_7ef1d_row4_col4, #T_7ef1d_row5_col5, #T_7ef1d_row6_col6, #T_7ef1d_row7_col7, #T_7ef1d_row8_col8, #T_7ef1d_row9_col9, #T_7ef1d_row10_col10 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_7ef1d_row0_col1, #T_7ef1d_row0_col2, #T_7ef1d_row0_col3, #T_7ef1d_row0_col4, #T_7ef1d_row0_col6, #T_7ef1d_row0_col7, #T_7ef1d_row0_col8, #T_7ef1d_row0_col9, #T_7ef1d_row0_col10, #T_7ef1d_row1_col0, #T_7ef1d_row1_col2, #T_7ef1d_row1_col3, #T_7ef1d_row1_col4, #T_7ef1d_row1_col5, #T_7ef1d_row1_col6, #T_7ef1d_row1_col7, #T_7ef1d_row1_col9, #T_7ef1d_row1_col10, #T_7ef1d_row2_col0, #T_7ef1d_row2_col1, #T_7ef1d_row2_col3, #T_7ef1d_row2_col4, #T_7ef1d_row2_col5, #T_7ef1d_row2_col6, #T_7ef1d_row2_col7, #T_7ef1d_row2_col8, #T_7ef1d_row2_col9, #T_7ef1d_row2_col10, #T_7ef1d_row3_col0, #T_7ef1d_row3_col1, #T_7ef1d_row3_col2, #T_7ef1d_row3_col4, #T_7ef1d_row3_col5, #T_7ef1d_row3_col7, #T_7ef1d_row3_col8, #T_7ef1d_row3_col9, #T_7ef1d_row3_col10, #T_7ef1d_row4_col0, #T_7ef1d_row4_col1, #T_7ef1d_row4_col2, #T_7ef1d_row4_col3, #T_7ef1d_row4_col5, #T_7ef1d_row4_col6, #T_7ef1d_row4_col7, #T_7ef1d_row4_col8, #T_7ef1d_row4_col9, #T_7ef1d_row4_col10, #T_7ef1d_row5_col0, #T_7ef1d_row5_col1, #T_7ef1d_row5_col2, #T_7ef1d_row5_col3, #T_7ef1d_row5_col4, #T_7ef1d_row5_col6, #T_7ef1d_row5_col8, #T_7ef1d_row5_col9, #T_7ef1d_row5_col10, #T_7ef1d_row6_col0, #T_7ef1d_row6_col1, #T_7ef1d_row6_col2, #T_7ef1d_row6_col3, #T_7ef1d_row6_col4, #T_7ef1d_row6_col5, #T_7ef1d_row6_col7, #T_7ef1d_row6_col8, #T_7ef1d_row6_col9, #T_7ef1d_row6_col10, #T_7ef1d_row7_col1, #T_7ef1d_row7_col2, #T_7ef1d_row7_col3, #T_7ef1d_row7_col4, #T_7ef1d_row7_col5, #T_7ef1d_row7_col6, #T_7ef1d_row7_col8, #T_7ef1d_row7_col9, #T_7ef1d_row7_col10, #T_7ef1d_row8_col0, #T_7ef1d_row8_col2, #T_7ef1d_row8_col3, #T_7ef1d_row8_col4, #T_7ef1d_row8_col5, #T_7ef1d_row8_col6, #T_7ef1d_row8_col7, #T_7ef1d_row8_col9, #T_7ef1d_row8_col10, #T_7ef1d_row9_col0, #T_7ef1d_row9_col1, #T_7ef1d_row9_col2, #T_7ef1d_row9_col3, #T_7ef1d_row9_col4, #T_7ef1d_row9_col6, #T_7ef1d_row9_col7, #T_7ef1d_row9_col8, #T_7ef1d_row9_col10, #T_7ef1d_row10_col1, #T_7ef1d_row10_col2, #T_7ef1d_row10_col3, #T_7ef1d_row10_col4, #T_7ef1d_row10_col5, #T_7ef1d_row10_col6, #T_7ef1d_row10_col7, #T_7ef1d_row10_col8, #T_7ef1d_row10_col9 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_7ef1d_row0_col5, #T_7ef1d_row9_col5 {
#   background-color: #280b53;
#   color: #f1f1f1;
# }
# #T_7ef1d_row1_col8, #T_7ef1d_row7_col0, #T_7ef1d_row10_col0 {
#   background-color: #210c4a;
#   color: #f1f1f1;
# }
# #T_7ef1d_row3_col6, #T_7ef1d_row5_col7 {
#   background-color: #160b39;
#   color: #f1f1f1;
# }
# #T_7ef1d_row8_col1 {
#   background-color: #1b0c41;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ef1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ef1d_level0_col0" class="col_heading level0 col0" >handshake</th>
#       <th id="T_7ef1d_level0_col1" class="col_heading level0 col1" >waving</th>
#       <th id="T_7ef1d_level0_col2" class="col_heading level0 col2" >yawning</th>
#       <th id="T_7ef1d_level0_col3" class="col_heading level0 col3" >walking</th>
#       <th id="T_7ef1d_level0_col4" class="col_heading level0 col4" >bowing</th>
#       <th id="T_7ef1d_level0_col5" class="col_heading level0 col5" >punching</th>
#       <th id="T_7ef1d_level0_col6" class="col_heading level0 col6" >standing</th>
#       <th id="T_7ef1d_level0_col7" class="col_heading level0 col7" >sitting</th>
#       <th id="T_7ef1d_level0_col8" class="col_heading level0 col8" >touchinghead</th>
#       <th id="T_7ef1d_level0_col9" class="col_heading level0 col9" >defending</th>
#       <th id="T_7ef1d_level0_col10" class="col_heading level0 col10" >reachingup</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ef1d_level0_row0" class="row_heading level0 row0" >handshake</th>
#       <td id="T_7ef1d_row0_col0" class="data row0 col0" >8.000000</td>
#       <td id="T_7ef1d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_7ef1d_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_7ef1d_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_7ef1d_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_7ef1d_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_7ef1d_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_7ef1d_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_7ef1d_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_7ef1d_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_7ef1d_row0_col10" class="data row0 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef1d_level0_row1" class="row_heading level0 row1" >waving</th>
#       <td id="T_7ef1d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_7ef1d_row1_col1" class="data row1 col1" >9.000000</td>
#       <td id="T_7ef1d_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_7ef1d_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_7ef1d_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_7ef1d_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_7ef1d_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_7ef1d_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_7ef1d_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_7ef1d_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_7ef1d_row1_col10" class="data row1 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef1d_level0_row2" class="row_heading level0 row2" >yawning</th>
#       <td id="T_7ef1d_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_7ef1d_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_7ef1d_row2_col2" class="data row2 col2" >11.000000</td>
#       <td id="T_7ef1d_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_7ef1d_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_7ef1d_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_7ef1d_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_7ef1d_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_7ef1d_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_7ef1d_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_7ef1d_row2_col10" class="data row2 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef1d_level0_row3" class="row_heading level0 row3" >walking</th>
#       <td id="T_7ef1d_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_7ef1d_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_7ef1d_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_7ef1d_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_7ef1d_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_7ef1d_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_7ef1d_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_7ef1d_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_7ef1d_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_7ef1d_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_7ef1d_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef1d_level0_row4" class="row_heading level0 row4" >bowing</th>
#       <td id="T_7ef1d_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_7ef1d_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_7ef1d_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_7ef1d_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_7ef1d_row4_col4" class="data row4 col4" >8.000000</td>
#       <td id="T_7ef1d_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_7ef1d_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_7ef1d_row4_col7" class="data row4 col7" >0.000000</td>
#       <td id="

# %% [markdown]
# ## CNN Network

# %%
dataset = flatten_dataset(master_dataset, level=1)
labels  = encode_labels(master_labels)
dataset = shuffle_dataset(dataset, labels)
train, train_label, test, test_label = train_test_split(dataset, train_test_ratio = 0.8, flatten_label=True)
# Out:
# Train dataset shape : (401, 216, 748)
# Test dataset shape  : (100, 216, 748)
# Train label shape   : (401, 11)
# Test label shape    : (100, 11)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.callbacks import TensorBoard


model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(216, 748, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(11, activation='softmax'))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model = train_wrapper(model, train, train_label, epochs=50, callbacks=[tb_callback])

model.summary()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 51s 4s/step - loss: 3.6515 - categorical_accuracy: 0.1696
# Epoch 2/50
# 13/13 [==============================] - 51s 4s/step - loss: 1.8925 - categorical_accuracy: 0.4239
# Epoch 3/50
# 13/13 [==============================] - 56s 4s/step - loss: 1.2147 - categorical_accuracy: 0.6135
# Epoch 4/50
# 13/13 [==============================] - 1927s 160s/step - loss: 0.7514 - categorical_accuracy: 0.7581
# Epoch 5/50
# 13/13 [==============================] - 939s 4s/step - loss: 0.5303 - categorical_accuracy: 0.8504
# Epoch 6/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.3105 - categorical_accuracy: 0.9102
# Epoch 7/50
# 13/13 [==============================] - 54s 4s/step - loss: 0.2138 - categorical_accuracy: 0.9202
# Epoch 8/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.2297 - categorical_accuracy: 0.9327
# Epoch 9/50
# 13/13 [==============================] - 54s 4s/step - loss: 0.1665 - categorical_accuracy: 0.9476
# Epoch 10/50
# 13/13 [==============================] - 51s 4s/step - loss: 0.0634 - categorical_accuracy: 0.9850
# Epoch 11/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.0593 - categorical_accuracy: 0.9825
# Epoch 12/50
# 13/13 [==============================] - 53s 4s/step - loss: 0.0415 - categorical_accuracy: 0.9850
# Epoch 13/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.0298 - categorical_accuracy: 0.9925
# Epoch 14/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.0310 - categorical_accuracy: 0.9950
# Epoch 15/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.0402 - categorical_accuracy: 0.9850
# Epoch 16/50
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 214, 746, 32)      320
#
#  max_pooling2d_2 (MaxPooling  (None, 107, 373, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 105, 371, 64)      18496
#
#  max_pooling2d_3 (MaxPooling  (None, 52, 185, 64)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 50, 183, 32)       18464
#
#  flatten_1 (Flatten)         (None, 292800)            0
#
#  dense_88 (Dense)            (None, 11)                3220811
#
# =================================================================
# Total params: 3,258,091
# Trainable params: 3,258,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
calculate_accuracy(model, test, test_label)
# Out:
# Accuracy: 0.9
# Prediction time for 100 samples : 4s
# <style type="text/css">
# #T_e0772_row0_col0, #T_e0772_row1_col1, #T_e0772_row2_col2, #T_e0772_row3_col3, #T_e0772_row4_col4, #T_e0772_row5_col5, #T_e0772_row6_col6, #T_e0772_row7_col7, #T_e0772_row8_col8, #T_e0772_row9_col9, #T_e0772_row10_col10 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_e0772_row0_col1, #T_e0772_row0_col2, #T_e0772_row0_col3, #T_e0772_row0_col4, #T_e0772_row0_col6, #T_e0772_row0_col7, #T_e0772_row0_col8, #T_e0772_row0_col9, #T_e0772_row0_col10, #T_e0772_row1_col0, #T_e0772_row1_col2, #T_e0772_row1_col3, #T_e0772_row1_col4, #T_e0772_row1_col5, #T_e0772_row1_col6, #T_e0772_row1_col7, #T_e0772_row1_col9, #T_e0772_row2_col0, #T_e0772_row2_col1, #T_e0772_row2_col3, #T_e0772_row2_col4, #T_e0772_row2_col5, #T_e0772_row2_col6, #T_e0772_row2_col7, #T_e0772_row2_col8, #T_e0772_row2_col9, #T_e0772_row2_col10, #T_e0772_row3_col0, #T_e0772_row3_col1, #T_e0772_row3_col2, #T_e0772_row3_col4, #T_e0772_row3_col5, #T_e0772_row3_col6, #T_e0772_row3_col7, #T_e0772_row3_col8, #T_e0772_row3_col9, #T_e0772_row3_col10, #T_e0772_row4_col0, #T_e0772_row4_col1, #T_e0772_row4_col2, #T_e0772_row4_col3, #T_e0772_row4_col5, #T_e0772_row4_col6, #T_e0772_row4_col7, #T_e0772_row4_col8, #T_e0772_row4_col9, #T_e0772_row4_col10, #T_e0772_row5_col0, #T_e0772_row5_col1, #T_e0772_row5_col2, #T_e0772_row5_col3, #T_e0772_row5_col4, #T_e0772_row5_col6, #T_e0772_row5_col7, #T_e0772_row5_col8, #T_e0772_row5_col9, #T_e0772_row5_col10, #T_e0772_row6_col0, #T_e0772_row6_col1, #T_e0772_row6_col2, #T_e0772_row6_col4, #T_e0772_row6_col5, #T_e0772_row6_col7, #T_e0772_row6_col8, #T_e0772_row6_col10, #T_e0772_row7_col0, #T_e0772_row7_col1, #T_e0772_row7_col2, #T_e0772_row7_col3, #T_e0772_row7_col4, #T_e0772_row7_col5, #T_e0772_row7_col6, #T_e0772_row7_col8, #T_e0772_row7_col9, #T_e0772_row7_col10, #T_e0772_row8_col0, #T_e0772_row8_col1, #T_e0772_row8_col2, #T_e0772_row8_col3, #T_e0772_row8_col4, #T_e0772_row8_col5, #T_e0772_row8_col6, #T_e0772_row8_col7, #T_e0772_row8_col9, #T_e0772_row8_col10, #T_e0772_row9_col0, #T_e0772_row9_col1, #T_e0772_row9_col2, #T_e0772_row9_col3, #T_e0772_row9_col4, #T_e0772_row9_col5, #T_e0772_row9_col6, #T_e0772_row9_col7, #T_e0772_row9_col8, #T_e0772_row9_col10, #T_e0772_row10_col0, #T_e0772_row10_col2, #T_e0772_row10_col3, #T_e0772_row10_col4, #T_e0772_row10_col5, #T_e0772_row10_col6, #T_e0772_row10_col7, #T_e0772_row10_col8, #T_e0772_row10_col9 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_e0772_row0_col5 {
#   background-color: #160b39;
#   color: #f1f1f1;
# }
# #T_e0772_row1_col8 {
#   background-color: #0e092b;
#   color: #f1f1f1;
# }
# #T_e0772_row1_col10 {
#   background-color: #4a0c6b;
#   color: #f1f1f1;
# }
# #T_e0772_row6_col3, #T_e0772_row6_col9 {
#   background-color: #210c4a;
#   color: #f1f1f1;
# }
# #T_e0772_row10_col1 {
#   background-color: #fca50a;
#   color: #000000;
# }
# </style>
# <table id="T_e0772">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0772_level0_col0" class="col_heading level0 col0" >handshake</th>
#       <th id="T_e0772_level0_col1" class="col_heading level0 col1" >waving</th>
#       <th id="T_e0772_level0_col2" class="col_heading level0 col2" >yawning</th>
#       <th id="T_e0772_level0_col3" class="col_heading level0 col3" >walking</th>
#       <th id="T_e0772_level0_col4" class="col_heading level0 col4" >bowing</th>
#       <th id="T_e0772_level0_col5" class="col_heading level0 col5" >punching</th>
#       <th id="T_e0772_level0_col6" class="col_heading level0 col6" >standing</th>
#       <th id="T_e0772_level0_col7" class="col_heading level0 col7" >sitting</th>
#       <th id="T_e0772_level0_col8" class="col_heading level0 col8" >touchinghead</th>
#       <th id="T_e0772_level0_col9" class="col_heading level0 col9" >defending</th>
#       <th id="T_e0772_level0_col10" class="col_heading level0 col10" >reachingup</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0772_level0_row0" class="row_heading level0 row0" >handshake</th>
#       <td id="T_e0772_row0_col0" class="data row0 col0" >8.000000</td>
#       <td id="T_e0772_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_e0772_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e0772_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_e0772_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_e0772_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_e0772_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_e0772_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_e0772_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_e0772_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_e0772_row0_col10" class="data row0 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e0772_level0_row1" class="row_heading level0 row1" >waving</th>
#       <td id="T_e0772_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_e0772_row1_col1" class="data row1 col1" >5.000000</td>
#       <td id="T_e0772_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e0772_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_e0772_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_e0772_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_e0772_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_e0772_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_e0772_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_e0772_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_e0772_row1_col10" class="data row1 col10" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e0772_level0_row2" class="row_heading level0 row2" >yawning</th>
#       <td id="T_e0772_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_e0772_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_e0772_row2_col2" class="data row2 col2" >9.000000</td>
#       <td id="T_e0772_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_e0772_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_e0772_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_e0772_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_e0772_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_e0772_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_e0772_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_e0772_row2_col10" class="data row2 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e0772_level0_row3" class="row_heading level0 row3" >walking</th>
#       <td id="T_e0772_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_e0772_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_e0772_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_e0772_row3_col3" class="data row3 col3" >8.000000</td>
#       <td id="T_e0772_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_e0772_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_e0772_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_e0772_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_e0772_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_e0772_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_e0772_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e0772_level0_row4" class="row_heading level0 row4" >bowing</th>
#       <td id="T_e0772_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_e0772_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_e0772_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_e0772_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T
col10, #T_f29d1_row9_col0, #T_f29d1_row9_col1, #T_f29d1_row9_col2, #T_f29d1_row9_col3, #T_f29d1_row9_col4, #T_f29d1_row9_col5, #T_f29d1_row9_col6, #T_f29d1_row9_col7, #T_f29d1_row9_col8, #T_f29d1_row9_col10, #T_f29d1_row10_col0, #T_f29d1_row10_col1, #T_f29d1_row10_col2, #T_f29d1_row10_col3, #T_f29d1_row10_col4, #T_f29d1_row10_col5, #T_f29d1_row10_col6, #T_f29d1_row10_col7, #T_f29d1_row10_col8, #T_f29d1_row10_col9 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f29d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f29d1_level0_col0" class="col_heading level0 col0" >handshake</th>
#       <th id="T_f29d1_level0_col1" class="col_heading level0 col1" >waving</th>
#       <th id="T_f29d1_level0_col2" class="col_heading level0 col2" >yawning</th>
#       <th id="T_f29d1_level0_col3" class="col_heading level0 col3" >walking</th>
#       <th id="T_f29d1_level0_col4" class="col_heading level0 col4" >bowing</th>
#       <th id="T_f29d1_level0_col5" class="col_heading level0 col5" >punching</th>
#       <th id="T_f29d1_level0_col6" class="col_heading level0 col6" >standing</th>
#       <th id="T_f29d1_level0_col7" class="col_heading level0 col7" >sitting</th>
#       <th id="T_f29d1_level0_col8" class="col_heading level0 col8" >touchinghead</th>
#       <th id="T_f29d1_level0_col9" class="col_heading level0 col9" >defending</th>
#       <th id="T_f29d1_level0_col10" class="col_heading level0 col10" >reachingup</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f29d1_level0_row0" class="row_heading level0 row0" >handshake</th>
#       <td id="T_f29d1_row0_col0" class="data row0 col0" >39.000000</td>
#       <td id="T_f29d1_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f29d1_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_f29d1_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f29d1_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f29d1_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_f29d1_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_f29d1_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_f29d1_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_f29d1_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_f29d1_row0_col10" class="data row0 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f29d1_level0_row1" class="row_heading level0 row1" >waving</th>
#       <td id="T_f29d1_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_f29d1_row1_col1" class="data row1 col1" >38.000000</td>
#       <td id="T_f29d1_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_f29d1_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_f29d1_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f29d1_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_f29d1_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_f29d1_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_f29d1_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_f29d1_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_f29d1_row1_col10" class="data row1 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f29d1_level0_row2" class="row_heading level0 row2" >yawning</th>
#       <td id="T_f29d1_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_f29d1_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_f29d1_row2_col2" class="data row2 col2" >37.000000</td>
#       <td id="T_f29d1_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_f29d1_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_f29d1_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_f29d1_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_f29d1_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_f29d1_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_f29d1_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_f29d1_row2_col10" class="data row2 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f29d1_level0_row3" class="row_heading level0 row3" >walking</th>
#       <td id="T_f29d1_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_f29d1_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_f29d1_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_f29d1_row3_col3" class="data row3 col3" >37.000000</td>
#       <td id="T_f29d1_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_f29d1_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_f29d1_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_f29d1_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_f29d1_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_f29d1_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_f29d1_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f29d1_level0_row4" class="row_heading level0 row4" >bowing</th>
#       <td id="T_f29d1_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_f29d1_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_f29d1_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_f29d1_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_f29d1_row4_col4" class="data row4 col4" >40.000000</td>
#       <td id="T_f29d1_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_f29d1_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_f29d1_row4_col7" class="data row4 col7" >0.000000</td>
#       <td id="T_f29d1_row4_col8" class="data row4 col8" >0.000000</td>
#       <td id="T_f29d1_row4_col9" class="data row4 col9" >0.000000</td>
#       <td id="T_f29d1_row4_col10" class="data row4 col10" >0.000000<
